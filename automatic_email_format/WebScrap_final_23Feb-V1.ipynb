# %% [markdown]
# top 5 companies
# old data
# 5000
# 3000

# %%
import pandas as pd
from automatic_email_format.scarpper_manager import scrapper_manager , fetch_google_results, fetch_yahoo_results,get_email_pattern
import time, math, random
from datetime import datetime, timedelta
from get_email_flags import get_flags
import ast
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 2
#       1 import pandas as pd
# ----> 2 from automatic_email_format.scarpper_manager import scrapper_manager , fetch_google_results, fetch_yahoo_results,get_email_pattern
#       3 import time, math, random
#       4 from datetime import datetime, timedelta
#
# ModuleNotFoundError: No module named 'automatic_email_format'

# %%
import pickle

# Read the pickle file
with open("/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/main_database/email_patterns.pkl", "rb") as file:
    data_dict = pickle.load(file)  # Load as a dictionary

# %%
data_dict['1 acord services']
# Out:
# ['FirstName.LastName@capitalone.com']

# %%
import pandas as pd
import os
# File paths
csv_file = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/missing_emails/remaining_missing.csv'

file_name = os.path.splitext(os.path.basename(csv_file))[0]

print(file_name)  # Output: remaining_missing

output_txt_file = file_name+".txt"
print (output_txt_file)
# Out:
# remaining_missing
# remaining_missing.txt

# %%
import pandas as pd
import os

# File paths
csv_file = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/missing_emails/remaining_missing.csv'

file_name = os.path.splitext(os.path.basename(csv_file))[0]
output_txt_file = file_name + ".txt"
checkpoint_file = "checkpoint.txt"

df = pd.read_csv(csv_file)
unique_companies = df["Company"].dropna().unique()  # Assuming 'company_name' is the column name
# Write unique company names to the output text file with index
with open(output_txt_file, "w") as f:
    for i, company in enumerate(unique_companies, start=0):
        f.write(f"{i} {company}\n")


# Read CSV file and extract unique company name

# %%
with open(output_txt_file, "r", encoding="utf-8") as file:
    company_list = [line.strip().split(maxsplit=1)[1] for line in file if line.strip()]

# Print the extracted list
print(company_list[last_index:2025])
# Out:
# ['360ns', '360yieldcenter', '365 digital dentistry lab', '37 main - a rock cafe-', '39 north', '3alpha', '3d cloud', '3d laboratories', '3d research corporation', '3d u.s. infantry regiment the old guard', '3g design', '3j-consulting', '3lb games', '3m thailand limited', '3mt', '3n1 renovations', '3rd dimension', '3rd infantry division', '3s mep + s', '3ten studio', '404 computer repair', '41st infantry brigade combat team', '47 west', '4b contracting services', '4cloud services', '4d communications', '4d distributor', '4d leaders', '4d systems automation', '4earth', '4est', '4fimd', '4-h center for youth development', '4hd', '4-horn power & hvac', '4-horn trench & shoring', '4impactdata', '4jet', '4kmap', '4leet', '4m analytics', '4m company', '4matic', '4p consulting', '4plastic', '4px', '4quartersit - it solutions & it support company in jacksonville', '4r real estate investment solutions', '4realsim', '4s bay partners', '4see', '4seeadvisory', '4sight counseling', '4site incorpor
# ...

# %%
with open(checkpoint_file, "w") as f:
    f.write(str(last_index) + "|" + output_txt_file)
print("Checkpoint file created.")

# Step 4: Read and print checkpoint file
with open(checkpoint_file, "r") as f:
    checkpoint_data = f.read().strip()
print(checkpoint_data)

# %%
# Update the checkpoint file with the last index
with open(checkpoint_file, "w") as f:
    f.write(f"{i} {output_txt_file}\n")

print(f"Unique company names saved to {output_txt_file}")
print(f"Checkpoint updated: {checkpoint_file} -> Last index: {i}")




# Write to a text file with index numbers
with open(output_txt_file, 'w') as f:
    for index, company in enumerate(unique_companies, start=1):
        f.write(f"{index}. {company}\n")

print(f"File '{output_txt_file}' created successfully with {len(unique_companies)} unique companies.")
# Out:
# Unique company names saved to remaining_missing.txt
# Checkpoint updated: checkpoint.txt -> Last index: 47921
# File 'remaining_missing.txt' created successfully with 47812 unique companies.

# %%
# Out:
# ['1 source consulting', '10 speed coffee bar', '100devs', '107.5 outlaw country', '10fold architecture + engineering', '10spot', '12 kings community development', '1-229 attack battalion', '133rd test squadron iowa air national guard', '139th security forces squadron', '1570 wptw', '16th judical circuit court', '16th judicial circuit court', '17a-4', '180 wealth adivsors', '1800 got junk', '184th wing', '185th air refueling wing', '186th air refueling wing', '1-888-4-abatement', '190th air refueling wing', '1st amendment records', '1st combat engineer battalion', '1st judicial district juvenile court services', '1st special forces group airborne u.s army', '1st window coverings', '2 brothers moving & delivery', '2 d construction', '2 green', '2 point construction', '2 pros remodeling', '2 t business solutions', '20/10 engineering group', '20/20 metals', '20/20 robotics', '20/20 studios', '2004 - may 2006 t-mobile', '2020 creative', '206 electric', '209 east lake shore drive corp.', '
# ...

# %%
output_txt_file
# Out:
# 'remaining_missing.txt'

# %%
# Define batch size
BATCH_SIZE = 2590

# Get the number of full batches
num_batches = len(queries) // BATCH_SIZE  # Number of complete batches
remainder = len(queries) % BATCH_SIZE  # Remaining elements in an extra batch (if any)

# Iterate over batches
for batch_idx in range(num_batches + (1 if remainder > 0 else 0)):  # Include remainder batch
    start_index = batch_idx * BATCH_SIZE
    end_index = min(start_index + BATCH_SIZE, len(queries))  # Avoid exceeding list size
    batch = queries[start_index:end_index]

    print (f"Batch:: {start_index}_{end_index}")
    # Print batch details
    namefile = f"Batch {start_index}_{end_index}__SCRAPPER_"
    print(namefile)
    df_raw= scrapper_manager(queries[start_index:end_index],namefile) 
    
    df_raw.to_csv(f"FinalDataBatch{namefile}9madddrch.csv")
    print (df_raw.shape)
    time.sleep(30)
#802mins
# 303 min 3044 file
# Out:
#        Unnamed: 0  Srl No                 Company      Contact Name  \
# 0               4      11     1 source consulting      Kim A Roesch
# 1               6      16     10 speed coffee bar    Danielle Craig
# 2               8      21                 100devs  Carlton Brackett
# 3               9      27                 100devs    Stephen Murphy
# 4              13      36    107.5 outlaw country     Dj Optamystik
# ...           ...     ...                     ...               ...
# 61879       69854  266926  zwilling j.a. henckels      Meghan Moore
# 61880       69855  266934                    zyde    Mabel Anderson
# 61881       69856  266937                zylabyte         Husna Ali
# 61882       69857  266947                    zync        Max Allred
# 61883       69858  266953                   zynga        Ouri Lahav
#
#       First Name   Last Name                       Designation  \
# 0            kim      roesch                 software engineer
# ...

# %%
print (missing_data[8024:])
# Out:
#                                                  Company
# 8024                                   logan machine co.
# 8025            logan-rogersville r-viii school district
# 8026                                               logc2
# 8027           logging department- a pv drilling company
# 8028                           logic general contracting
# ...                                                  ...
# 19995                            russell-filand builders
# 19996                              russellville hospital
# 19997  russellville hospital - a curae healthcare aff...
# 19998             russellville park retirement community
# 19999                           russtech engineering co.
#
# [11976 rows x 1 columns]

# %%
# Out:
# 61884
# ...

# %%
# Define batch size
BATCH_SIZE = 2590

# Get the number of full batches
num_batches = len(queries) // BATCH_SIZE  # Number of complete batches
remainder = len(queries) % BATCH_SIZE  # Remaining elements in an extra batch (if any)

# Iterate over batches
for batch_idx in range(num_batches + (1 if remainder > 0 else 0)):  # Include remainder batch
    start_index = batch_idx * BATCH_SIZE
    end_index = min(start_index + BATCH_SIZE, len(queries))  # Avoid exceeding list size
    batch = queries[start_index:end_index]

    print (f"Batch:: {start_index}_{end_index}")
    # Print batch details
    namefile = f"Batch {start_index}_{end_index}__SCRAPPER_"
    print(namefile)
    df_raw= scrapper_manager(queries[start_index:end_index],namefile) 
    
    df_raw.to_csv(f"FinalDataBatch{namefile}9madddrch.csv")
    print (df_raw.shape)
    time.sleep(30)
#802mins
# 303 min 3044 file
# Out:
# Batch:: 0_2590
# Batch 0_2590__SCRAPPER_
# printing lenghth 2590
# Number of batch: 31  and each batch have  85  many rows
# 2025-03-19
# Batch-------------------------------------- 0
#  Failed to fetch results for query '28gorilla': HTTPSConnectionPool(host='www.google.com', port=443): Read timed out. (read timeout=5)
# sleeping after batch
# createCSV
# Batch-------------------------------------- 1
# sleeping after batch
# createCSV
# Batch-------------------------------------- 2
# sleeping after batch
# createCSV
# Batch-------------------------------------- 3
# sleeping after batch
# createCSV
# Batch-------------------------------------- 4
# ...

# %%
queries[start_index:end_index]
# Out:
# ['linux new media',
#  'linvest21',
#  'linwood mining',
#  'linwood mining & minerals',
#  'linwood mining and minerals',
#  'linwood ymca',
#  'linx solutions',
#  'lion cg',
#  'lion chaser development group',
#  'lion heart kombucha',
#  'lion imagery',
#  'lionbridge games',
#  'lionhardt organization',
#  'lionheart recovery center',
#  'lions capital mortgage',
#  'lions financial',
#  'lions healthfirst foundation',
#  'lions legal group',
#  'lions world vision institute formerly sightlife',
#  'lipaworld',
#  'lipe property co',
#  'lipedema project',
#  "lipic's engagement",
#  'lippbros',
#  'lippert mechanical service',
#  'lipton tea and infusions',
#  'lipton teas and infusions',
#  'liquid automation systems - south africa',
#  'liquid automation systems - usa',
#  'liquid life vacation rentals',
#  'liquid machines',
#  'liquid mercury',
#  'liquid recovery solutions',
#  'liquid rocketry at illinois',
#  'liquid spark',
# ...

# %%
df_raw.to_csv("rawdatatoday.csv")

# %%
final =get_flags(df_raw, 'email_list')

# %%
# Add a new column that assigns a sequence number within each group
df_raw.to_csv("rawdata.csv")

df_raw["number"] = df_raw.groupby("company").cumcount() + 1

df_raw.to_csv("finalRawData.csv")

# %%
filter_df = df_raw[df_raw['email_list'] != "Not Found"]
filter_df.to_csv("filterdataemails.csv")
filter_df.head(3)
# Out:
#                                  company  \
# 1      city of virginia beach-skillquest
# 2      city of virginia beach-skillquest
# 6  city of virginia beach human services
#
#                                              website  \
# 1                                    hsvirginiabeach
# 2  rocketreachco/department-of-behavioral-health-...
# 6                                    hsvirginiabeach
#
#                        email_list  engine accuracy  \
# 1  [foiacouncil@dls.virginia.gov]  Google  Unknown
# 2       [last@dbhds.virginia.gov]  Google     99.0
# 6  [foiacouncil@dls.virginia.gov]  Google  Unknown
#
#                                              snippet              domain  \
# 1   The Council may be contacted by e-mail at foi...    dls.virginia.gov
# 2   Department of Behavioral Health and Developme...  dbhds.virginia.gov
# 6   The Council may be contacted by e-mail at foi...    dls.virginia.gov
#
#   match                                 email_formats_list  \
# ...

# %%
# import os
# import pandas as pd

# def read_files_from_directory(parent_dir):
#     """
#     Recursively searches for CSV and Excel files in a given directory and all its subdirectories.
#     Reads the files into Pandas DataFrames and stores them in a dictionary.
    
#     :param parent_dir: Path to the parent directory.
#     :return: Dictionary with filenames as keys and DataFrames as values.
#     """
#     data_frames = {}

#     # Walk through all folders and subfolders
#     for root, _, files in os.walk(parent_dir):
#         for file in files:
#             file_path = os.path.join(root, file)
            
#             # Check if the file is a CSV
#             if file.endswith(".csv"):
#                 try:
#                     df = pd.read_csv(file_path)
#                     data_frames[file_path] = df
#                     print(f"Loaded CSV: {file_path}")
#                 except Exception as e:
#                     print(f"Error reading CSV {file_path}: {e}")

#             # Check if the file is an Excel file
#             elif file.endswith(".xlsx") or file.endswith(".xls"):
#                 try:
#                     df = pd.read_excel(file_path)
#                     data_frames[file_path] = df
#                     print(f"Loaded Excel: {file_path}")
#                 except Exception as e:
#                     print(f"Error reading Excel {file_path}: {e}")

#     return data_frames

# # Example usage
# parent_directory = "/Users/sumanverma/Documents/Work/Email_tool/email_creator_app"  # Change this to your directory
# dataframes = read_files_from_directory(parent_directory)

# # Print the keys (file paths) of loaded DataFrames
# print("\nLoaded DataFrames:")
# for file_path in dataframes:
#     print(file_path)

# %%
import pandas as pd
import difflib
import re

def extract_domain(email_pattern):
    """Extract domain from the email pattern."""
    match = re.search(r'@([\w.-]+)', str(email_pattern))  # Convert to string (handle NaN)
    return match.group(1) if match else None

def similarity_score(company, domain):
    """Compare similarity between company name and domain."""
    company_clean = re.sub(r'[^a-zA-Z0-9]', '', str(company)).lower()
    domain_clean = re.sub(r'\..*$', '', str(domain)).lower()  # Remove TLD (.com, .edu)

    score = difflib.SequenceMatcher(None, company_clean, domain_clean).ratio()

    if score > 0.8:
        return "High"
    elif score > 0.4:
        return "Medium"
    else:
        return "Low"

def get_best_email(company, email_list):
    """Select the best email and its similarity score (High, Medium, Low)."""
    best_score = None
    best_email = None
    best_flag = None

    for email in email_list:
        domain = extract_domain(email)
        score = similarity_score(company, domain)
        
        if best_score is None or \
           (score == "High" and best_score != "High") or \
           (score == "Medium" and best_score not in ["High", "Medium"]) or \
           (score == "Low" and best_score == "Low"):
            best_score = score
            best_email = email
            best_flag = score  # Store the flag

    return best_email, best_flag

# Example dataframe
data = {
    'company': [
        'minnesota exteriors', 'minnesota exteriors', 'mit department of biological engineering',
        'lincoln foodservice', 'lincoln foodservice', 'usa bluebook', 'usa bluebook',
        'usa bluebook', 'connectivity standards alliance', 'connectivity standards alliance', 
        'south florida surgical specialists, llc'
    ],
    'email_list': [
        ['jane.doe@minnesotaexteriors.com'],
        ['jsmith@northernexteriorsmn.com'],
        ['jdoe@mit.edu'],
        ['jdoe@lincolnfp.com'],
        ['jane.doe@lincolnindustries.com'],
        ['jdoe@usabluebook.com'],
        ['John.Smith@usabluebook.com', 'JSmith@usabluebook.com'],
        ['jdoe@thebluebook.com'],
        ['jsmith@csa-iot.org'],
        ['jsmith@csa-iot.org'],
        ['jsmith@miamivipsurgery.com']
    ]
}

df = pd.DataFrame(data)
print (df)
# Apply function to get best email and similarity score
df[['best_email', 'match_flag']] = df.apply(lambda row: pd.Series(get_best_email(row['company'], row['email_list'])), axis=1)

print(df[['company', 'best_email', 'match_flag']])

# %%
final =get_flags(df, 'email pattern')

# %%
# ,company,Website,Email,Engine,Accuracy,Snippet,email pattern

# %%
import pandas as pd
import glob
import os

# Define folder path
folder_path = "/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/testFile" # Replace with the actual folder path
# Get all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# %%
import pandas as pd
import re
from get_email_flags import get_flags
# Create an empty list to store DataFrames
dfs = []

# Loop through CSV files and read them
for file in csv_files:
    print (file)
    df = pd.read_csv(file)  # Read CSV file]
    print ('Companies: ', len(df['company'].unique()))
    print (df.shape)
    dfs.append(df)  # Append to list
    print ("-"*80)

# Combine all DataFrames into one
df_combined = pd.concat(dfs, ignore_index=True)
print (df_combined.shape)
df_combined = df_combined.drop_duplicates()

print (df_combined.shape)

# %%
from scrapper_data_process import get_emailPattern_flags

get_emailPattern_flags(df_combined)

# %%
csv_file = r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/BBatch 0_2590_5_2025-03-01.csv"

# %%
csv_file = r'/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/BBatch 0_2590_35_2025-03-01.csv'



# Loop through CSV files and read them
for file in csv_files:
    print (file)
    df = pd.read_csv(file)  # Read CSV file]
    print ('Companies: ', len(df['company'].unique()))
    print (df.shape)
    dfs.append(df)  # Append to list

# Combine all DataFrames into one
df_combined = pd.concat(dfs, ignore_index=True)

# Print the combined DataFrame info
print(df_combined.shape)
print ('Companies: ', len(df_combined['company'].unique()))
# Save the merged DataFrame (optional)
df_combined.to_csv("combined_output_missing.csv", index=False)

# %%
import pandas as pd
import difflib
import re

# Path to your CSV file
csv_file = r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails/always_test_no_change_output.csv"

def extract_domain(email_pattern):
    """Extract domain from the email pattern."""
    match = re.search(r'@([\w.-]+)', str(email_pattern))  # Convert to string (handle NaN)
    return match.group(1) if match else None

def similarity_score(company, domain):
    """Compare similarity between company name and domain."""
    company_clean = re.sub(r'[^a-zA-Z0-9]', '', str(company)).lower()
    domain_clean = re.sub(r'\..*$', '', str(domain)).lower()  # Remove TLD (.com, .edu)

    score = difflib.SequenceMatcher(None, company_clean, domain_clean).ratio()

    if score > 0.8:
        return "High"
    elif score > 0.4:
        return "Medium"
    else:
        return "Low"
print (str(datetime.now())[:10])
# Load CSV
# df = pd.read_csv(csv_file)
df = df_combined
# Ensure required columns exist
if "Company" in df.columns and "Email" in df.columns:
    # Extract domains and compute similarity
    df["domain"] = df["Email"].apply(extract_domain)
    df["match"] = df.apply(lambda row: similarity_score(row["Company"], row["domain"]) if row["domain"] else "N/A", axis=1)

    # Save back to CSV
    output_csv = f"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/Updated_EmailPatterns-{str(datetime.now())[:10]}.csv"
    df.to_csv(output_csv, index=False)

    print(f"Updated CSV saved to: {output_csv}")
else:
    print("Error: CSV file must contain 'company' and 'email pattern' columns.")

# %%
from get_email_flags import get_flags
output_csv = f"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/Updated_EmailPatterns-{str(datetime.now())[:10]}.csv"

get_flags(df_combined,output_csv)

# %%
# Load CSV
df = pd.read_csv("FirstBatch-dddd.csv")

# Ensure required columns exist
if "company" in df.columns and "email pattern" in df.columns:
    # Extract domains and compute similarity
    df["domain"] = df["email pattern"].apply(extract_domain)
    df["match"] = df.apply(lambda row: similarity_score(row["company"], row["domain"]) if row["domain"] else "N/A", axis=1)

    # Save back to CSV
    output_csv = "/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/Updated_EmailPatterns2.csv"
    df.to_csv(output_csv, index=False)

    print(f"Updated CSV saved to: {output_csv}")
else:
    print("Error: CSV file must contain 'company' and 'email pattern' columns.")

# %% [markdown]
# import pandas as pd
# import os
#
# def split_large_file(file_path, output_folder, chunk_size=80000):
#     # Check file type
#     file_extension = os.path.splitext(file_path)[1].lower()
#
#     # Read the file
#     if file_extension == ".csv":
#         df = pd.read_csv(file_path)
#     elif file_extension in [".xls", ".xlsx"]:
#         df = pd.read_excel(file_path)
#     else:
#         raise ValueError("Unsupported file format. Please provide a CSV or Excel file.")
#
#     total_rows = len(df)
#     num_parts = -(-total_rows // chunk_size)  # Equivalent to math.ceil(total_rows / chunk_size)
#
#     # Create output folder if it doesn't exist
#     os.makedirs(output_folder, exist_ok=True)
#
#     print(f"Total rows: {total_rows}, Splitting into {num_parts} parts.")
#
#     for i in range(num_parts):
#         start_row = i * chunk_size
#         end_row = min((i + 1) * chunk_size, total_rows)
#         df_chunk = df.iloc[start_row:end_row]
#
#         output_file = os.path.join(output_folder, f"split_part_{i+1}{file_extension}")
#
#         if file_extension == ".csv":
#             df_chunk.to_csv(output_file, index=False)
#         else:
#             df_chunk.to_excel(output_file, index=False)
#
#         print(f"Saved: {output_file} with {len(df_chunk)} rows")
#
# # Example usage:
# # split_large_file("data.csv", "output_folder")

# %%
import pandas as pd
import os

def split_large_file(file_path, output_folder, chunk_size=80000):
    # Check file type
    file_extension = os.path.splitext(file_path)[1].lower()
    
    # Read the file
    if file_extension == ".csv":
        df = pd.read_csv(file_path)
    elif file_extension in [".xls", ".xlsx"]:
        df = pd.read_excel(file_path)
    else:
        raise ValueError("Unsupported file format. Please provide a CSV or Excel file.")
    
    total_rows = len(df)
    num_parts = -(-total_rows // chunk_size)  # Equivalent to math.ceil(total_rows / chunk_size)
    
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    print(f"Total rows: {total_rows}, Splitting into {num_parts} parts.")
    
    for i in range(num_parts):
        start_row = i * chunk_size
        end_row = min((i + 1) * chunk_size, total_rows)
        df_chunk = df.iloc[start_row:end_row]
        
        output_file = os.path.join(output_folder, f"split_part_{i+1}{file_extension}")
        
        if file_extension == ".csv":
            df_chunk.to_csv(output_file, index=False)
        else:
            df_chunk.to_excel(output_file, index=False)
        
        print(f"Saved: {output_file} with {len(df_chunk)} rows")

# Example usage:
split_large_file("/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/21-Feb_Formatte_Missing_file2025-02-25 22-18-35.csv", "/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files")

# %%
import os
import pandas as pd

def combine_and_filter_csv(folder_path, output_file):
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    df_list = []

    # Read all CSV files and combine into one DataFrame
    for file in all_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        df_list.append(df)

        df['Email'] = df['Email'].fillna("NA")

        print (df.shape)
        print   ( '-----------',   df[df['Email'] != "NA"].shape)



    
    combined_df = pd.concat(df_list, ignore_index=True)



    # Filter rows where 'email' column is not empty
    filtered_df = combined_df
    filtered_df =filtered_df[(filtered_df['Email'].str.strip() != "NA")]

    # Save the cleaned data to a new CSV
    filtered_df.to_csv(output_file, index=False)
    print(f"Filtered CSV saved to: {output_file}")
    print (filtered_df.shape)
    print (filtered_df.head(2))
    return filtered_df

# Example usage
filtered_df = combine_and_filter_csv(r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails", "filtered_output.csv")

# %%
import os
import pandas as pd

def combine_and_filter_csv(folder_path, output_file):
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    df_list = []

    # Read all CSV files and combine into one DataFrame
    for file in all_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        df_list.append(df)

        df['Email'] = df['Email'].fillna("NA")

        print (df.shape)
        print   ( '-----------',   df[df['Email'] != "NA"].shape)



    
    combined_df = pd.concat(df_list, ignore_index=True)



    # Filter rows where 'email' column is not empty
    filtered_df = combined_df
    filtered_df =filtered_df[(filtered_df['Email'].str.strip() != "NA")]

    # Save the cleaned data to a new CSV
    filtered_df.to_csv(output_file, index=False)
    print(f"Filtered CSV saved to: {output_file}")
    print (filtered_df.shape)
    print (filtered_df.head(2))
    return filtered_df

# Example usage
filtered_df = combine_and_filter_csv(r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails", "filtered_output.csv")


columns = ['unnamed: 0', 'srl no', 'company', 'contact name', 'first name',
       'last name', 'designation', 'location', 'industry', 'mailer_status',
       'email', 'domain', 'match']

# %%
import os
import pandas as pd

def combine_and_filter_csv(folder_path, output_file):
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    df_list = []

    # Read all CSV files and combine into one DataFrame
    for file in all_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        df_list.append(df)

        df['Email'] = df['Email'].fillna("NA")

        print (df.shape)
        print   ( '-----------',   df[df['Email'] != "NA"].shape)



    
    combined_df = pd.concat(df_list, ignore_index=True)



    # Filter rows where 'email' column is not empty
    filtered_df = combined_df
    filtered_df =filtered_df[(filtered_df['Email'].str.strip() != "NA")]

    # Save the cleaned data to a new CSV
    filtered_df.to_csv(output_file, index=False)
    print(f"Filtered CSV saved to: {output_file}")
    print (filtered_df.shape)
    print (filtered_df.head(2))
    return filtered_df

# Example usage
filtered_df = combine_and_filter_csv(r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails", "filtered_output.csv")


columns = ['unnamed: 0', 'srl no', 'company', 'contact name', 'first name',
       'last name', 'designation', 'location', 'industry', 'mailer_status',
       'email', 'domain', 'match']


from get_email_flags import get_flags
output_csv = f"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/EmailResults-{str(datetime.now())[:10]}.csv"

get_flags(filtered_df,output_csv)

# %%
import os
import pandas as pd

def combine_and_filter_csv(folder_path, output_file):
    all_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    df_list = []

    # Read all CSV files and combine into one DataFrame
    for file in all_files:
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        df_list.append(df)

        df['Email'] = df['Email'].fillna("NA")

        print (df.shape)
        print   ( '-----------',   df[df['Email'] != "NA"].shape)



    
    combined_df = pd.concat(df_list, ignore_index=True)



    # Filter rows where 'email' column is not empty
    filtered_df = combined_df
    filtered_df =filtered_df[(filtered_df['Email'].str.strip() != "NA")]

    # Save the cleaned data to a new CSV
    filtered_df.to_csv(output_file, index=False)
    print(f"Filtered CSV saved to: {output_file}")
    print (filtered_df.shape)
    print (filtered_df.head(2))
    return filtered_df

# Example usage
filtered_df = combine_and_filter_csv(r"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/files/created_emails", "filtered_output.csv")


columns = ['unnamed: 0', 'srl no', 'company', 'contact name', 'first name',
       'last name', 'designation', 'location', 'industry', 'mailer_status',
       'email', 'domain', 'match']


from get_email_flags import get_flags
output_csv = f"/Users/sumanverma/Documents/Work/Email_tool/email_creator_app/automatic_email_format/EmailResults-{str(datetime.now())[:10]}.csv"

get_flags(filtered_df,output_csv)
import pandas as pd

# Load the DataFrame from the CSV file
df = pd.read_csv("your_file.csv")  # Replace with the actual file path

# Filter out rows where the 'Email' column is empty or 'NA'
df_filtered = df[(df['Email'].notna()) & (df['Email'].str.strip() != "NA") & (df['Email'].str.strip() != "")]

# Save the filtered DataFrame to a new CSV file
df_filtered.to_csv("filtered_emails.csv", index=False)

print("Filtered data saved to filtered_emails.csv")

# %%
import smtplib

def validate_email(email):
    domain = email.split("@")[-1]
    try:
        server = smtplib.SMTP(f"mx.{domain}")
        server.helo()
        server.mail("me@example.com")
        code, message = server.rcpt(email)
        server.quit()

        return code == 250  # 250 means valid email
    except:
        return False

# Example
print(validate_email("sumanece309@gmail.com"))

# %%
import os
import time
import pandas as pd

output_path = r'email_creator_app/files/missing_emails/EW-ND-10Mar-_fo_Missing_file2025-03-10 14-33-02_missing.csv'
checkpoint_path = 'progress_checkpoint.txt'  # File to track last completed batch
output_path = output_path[:5]
# Read the CSV file
missing_data = pd.read_csv(output_path)

queries = [str(i) for i in missing_data['Company']]
print(f"Total queries: {len(queries)}")

# Define batch size
BATCH_SIZE = 2590

# Get total number of batches
num_batches = len(queries) // BATCH_SIZE
remainder = len(queries) % BATCH_SIZE

# Determine where to start
last_completed_batch = -1  # Default to start from the beginning
if os.path.exists(checkpoint_path):
    with open(checkpoint_path, 'r') as f:
        last_completed_batch = int(f.read().strip())

print(f"Resuming from batch: {last_completed_batch + 1}")

# Iterate over batches
for batch_idx in range(last_completed_batch + 1, num_batches + (1 if remainder > 0 else 0)):
    start_index = batch_idx * BATCH_SIZE
    end_index = min(start_index + BATCH_SIZE, len(queries))
    batch = queries[start_index:end_index]

    print(f"Processing Batch {start_index}_{end_index}")
    namefile = f"Batch {start_index}_{end_index}__SCRAPPER_"

    try:
        df_raw = scrapper_manager(batch, namefile)
        df_raw.to_csv(f"FinalDataBatch{namefile}9madddrch.csv")
        print(f"Batch {start_index}_{end_index} saved. Shape: {df_raw.shape}")

        # Update checkpoint
        with open(checkpoint_path, 'w') as f:
            f.write(str(batch_idx))

    except Exception as e:
        print(f"Error in batch {batch_idx}: {e}")
        break  # Stop the loop so the issue can be fixed

    time.sleep(30)  # Pause between batches
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       7 output_path = output_path[:5]
#       8 # Read the CSV file
# ----> 9 missing_data = pd.read_csv(output_path)
#      11 queries = [str(i) for i in missing_data['Company']]
#      12 print(f"Total queries: {len(queries)}")
#
# ...

# %%
import googlesearch
print(googlesearch.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import googlesearch
# ----> 2 print(googlesearch.__version__)
#
# AttributeError: module 'googlesearch' has no attribute '__version__'

# %%
import requests
from bs4 import BeautifulSoup
from googlesearch import search


def fetch_google_results(query, proxy, num_results=5):

    results = list(search(query, num_results=5, proxy =proxy,  advanced= True) ) # Fetch up to 4 results
    data=[]
    for i, result in enumerate(results, start=5):

        data.append({'title': result.title, 'link': result.url, 'snippet': result.description})
    return data

    # If no results are found, return a single entry with "NA" values
    if not results:
        results.append({'title': 'NA', 'link': 'NA', 'snippet': 'NA'})
        
    return results

# %%
proxy1 = "http://proxyuser:emailtool@173.224.122.122:3128"  # tvllV5sSSczc  ll

proxy2 = "http://proxyuser:emailtool@173.224.122.126:3129"

proxy3 = "http://proxyuser:emailtool@173.224.122.123:3130"

proxy4 = "http://proxyuser:emailtool@173.224.122.109:3127"



# curl -x http://proxyuser:emailtool@173.224.122.122:3128 http://httpbin.org/ip

# %%
from googlesearch import search




proxy = proxy1
# or for socks5
# proxy = 'socks5://username:password@proxy.host.com:1080/'

j = search("proxy test", num_results=100, lang="en", proxy=proxy, ssl_verify=False)
for i in j:
    print(i)

# %%
fetch_google_results("what is email format for Amazon", proxy=proxy1)
# Out:
# []

# %%
import os, re, tempfile

def recover_from_logs(log_file, output_txt_file, checkpoint_file):
    last_company = None
    total_results = 0

    # --- Step 1: read log file backwards ---
    with open(log_file, "r", encoding="latin1") as f:
        for line in reversed(f.readlines()):
            # Capture last "RESULTS: -------> nnnn"
            match_results = re.search(r"RESULTS:\s*------->\s*(\d+)", line)
            if match_results and total_results == 0:
                total_results = int(match_results.group(1))

            # Capture last company
            if "QUERY:" in line and last_company is None:
                match = re.search(r"QUERY:\s*(.*?)(?:\||RESULTS:|$)", line)
                if match:
                    last_company = match.group(1).strip()

            if last_company and total_results:
                break  # we got both → stop scanning

    if not last_company:
        print("⚠️ No company found in logs. Starting from index 0.")
        return 0, output_txt_file, 0

    # --- Step 2: find index in output file ---
    last_index = 0
    with open(output_txt_file, "r", encoding="latin1") as f:
        for line in f:
            parts = line.strip().split(maxsplit=1)
            if len(parts) == 2:
                idx, company = parts
                if company.strip().lower() == last_company.lower():
                    last_index = int(idx)
                    break

    # --- Step 3: relative file path (folder + filename only) ---
    folder = os.path.basename(os.path.dirname(output_txt_file))
    filename = os.path.basename(output_txt_file)
    relative_name = os.path.join(folder, filename) if folder else filename

    # --- Step 4: write checkpoint safely ---
    dir_name = os.path.dirname(checkpoint_file) or "."
    with tempfile.NamedTemporaryFile("w", delete=False, dir=dir_name, suffix=".tmp") as tmp_file:
        tmp_file.write(f"{last_index} {relative_name} {total_results}\n")
        tmp_file.flush()
        os.fsync(tmp_file.fileno())
        temp_file_name = tmp_file.name

    os.replace(temp_file_name, checkpoint_file)

    return last_index, relative_name, total_results

# %%
log_file = r'E:\EmailTool-V2\Barzaan\email_creator_app\track_automation\logs_for_tracking2025-08-16.txt'
output_txt_file = r'E:\EmailTool-V2\Barzaan\email_creator_app\track_automation\USA-ND-PMP-11Aug-ForCreation_missing_Companies.txt'
checkpoint_file = r'E:\EmailTool-V2\Barzaan\email_creator_app\track_automation\USA-ND-PMP-11Aug-ForCreation_missing_CheckPoint.txt'

# %%
recover_from_logs(log_file, output_txt_file, checkpoint_file)
# Out:
# (5528,
#  'track_automation\\USA-ND-PMP-11Aug-ForCreation_missing_Companies.txt',
#  1594)

# %%
import re, os

def get_latest_log_file(log_path):
    """
    Find the latest 'logs_for_tracking*.txt' file in the given directory.
    Prioritizes today's file (2025-08-26), otherwise uses modification time.
    """

    log_dir = os.path.dirname(log_path)
    today_file = os.path.join(log_dir, 'logs_for_tracking2025-08-26.txt')
    latest_file = None
    latest_mtime = None

    # Check if today's file exists
    if os.path.exists(today_file):
        print("📄 Latest log file:", today_file)
        return today_file

    # If today's file doesn't exist, find the latest by modification time
    for fname in os.listdir(log_dir):
        if re.match(r"logs_for_tracking\d{4}-\d{2}-\d{2}\.txt", fname):
            full_path = os.path.join(log_dir, fname)
            file_mtime = os.path.getmtime(full_path)

            if latest_mtime is None or file_mtime > latest_mtime:
                latest_mtime = file_mtime
                latest_file = full_path

    print("📄 Latest log file:", latest_file)
    return latest_file
# Out:
# 📄 Latest log file: E:\EmailTool-V2\Barzaan\email_creator_app\track_automation\logs_for_tracking2025-08-24.txt
# 'E:\\EmailTool-V2\\Barzaan\\email_creator_app\\track_automation\\logs_for_tracking2025-08-24.txt'

# %%
import os

log_path = 'E:\\EmailTool-V2\\Barzaan\\email_creator_app\\track_automation\\logs_for_tracking2025-08-25.txt'
folder_path = os.path.dirname(log_path)

print("Folder path:", folder_path)
# Out:
# Folder path: E:\EmailTool-V2\Barzaan\email_creator_app\track_automation

# %%
batch_size = 100
total_entries = 500

flag = False  # Initial value

for i in range(0, total_entries, batch_size):
    batch_start = i
    batch_end = min(i + batch_size, total_entries)

    print(f"Processing entries {batch_start} to {batch_end - 1}, flag = {flag}")

    # Your batch logic here using `flag`

    flag = not flag  # Flip the flag after each batch
# Out:
# Processing entries 0 to 99, flag = False
# Processing entries 100 to 199, flag = True
# Processing entries 200 to 299, flag = False
# Processing entries 300 to 399, flag = True
# Processing entries 400 to 499, flag = False
